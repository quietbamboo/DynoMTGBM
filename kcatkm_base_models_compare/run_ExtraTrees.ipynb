# %% [markdown]
# # ExtraTrees

# %%
import os.path
import json
import pandas as pd
from sklearn.ensemble import ExtraTreesRegressor
import numpy as np
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from scipy.stats import pearsonr
from hyperopt import fmin, tpe, hp, Trials, space_eval
from copy import deepcopy
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")
from sklearnex import patch_sklearn
patch_sklearn()
current_dir = os.getcwd()


def return_scores(y_true, y_pred):
    y_true = np.array(y_true).ravel()
    y_pred = np.array(y_pred).ravel()
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    pcc = pearsonr(y_true, y_pred)[0]
    return rmse, mae, r2, pcc

def return_x_y(df_filtered):
    y = df_filtered[label_name].values
    mask = ~np.isnan(y)

    # factors
    auxiliary_data = []
    if use_t_ph_embedding:
        ph = df_filtered['ph'].values.reshape(-1, 1)
        t = df_filtered['t'].values.reshape(-1, 1)
        auxiliary_data.append(ph)
        auxiliary_data.append(t)

    if use_mw_logp:
        mw = df_filtered['mw'].values.reshape(-1, 1)
        logp = df_filtered['logp'].values.reshape(-1, 1)
        auxiliary_data.append(mw)
        auxiliary_data.append(logp)

    protein_data = np.array(df_filtered[protein_column].tolist())
    substrate_data = np.array(df_filtered[substrate_column].tolist())
    x = np.hstack([protein_data, substrate_data] + auxiliary_data)

    return x[mask], y[mask]

def search_params(params):
    print(params)
    temp_params = deepcopy(params)
    temp_params["n_estimators"] = int(temp_params["n_estimators"])
    temp_params["max_depth"] = int(temp_params["max_depth"])
    temp_params["min_samples_split"] = int(temp_params["min_samples_split"])
    temp_params["min_samples_leaf"] = int(temp_params["min_samples_leaf"])

    val_scores_list = []
    for train_index, val_index in kf.split(df_train_val):
        df_train = df_train_val.iloc[train_index]
        df_val = df_train_val.iloc[val_index]

        train_x, train_y = return_x_y(df_train)
        val_x, val_y = return_x_y(df_val)

        model = ExtraTreesRegressor(**temp_params, random_state=random_state, n_jobs=-1)
        model.fit(train_x, train_y)

        val_predicted = model.predict(val_x)
        val_scores = return_scores(val_y, val_predicted)
        val_scores_list.append(val_scores)

    val_scores_mean = np.mean(val_scores_list, axis=0)
    print(f"[Val_mean] rmse {val_scores_mean[0]:.3f} mae {val_scores_mean[1]:.3f} r2 {val_scores_mean[2]:.3f} pcc {val_scores_mean[3]:.3f}")

    return val_scores_mean[0]

def search_best_param(max_evals):
    space = {
        "n_estimators": hp.randint("n_estimators", 10, 300),
        "max_depth": hp.randint("max_depth", 5, 20),
        "min_samples_split": hp.randint("min_samples_split", 2, 20),
        "min_samples_leaf": hp.randint("min_samples_leaf", 1, 20),
        "max_features": hp.uniform("max_features", 0.5, 1.0),
    }

    trials = Trials()
    print(f'[Info] Starting parameter search...')
    best_params = fmin(fn=search_params, space=space, algo=tpe.suggest, max_evals=max_evals, trials=trials)
    best_params["n_estimators"] = int(best_params["n_estimators"])
    best_params["max_depth"] = int(best_params["max_depth"])
    best_params["min_samples_split"] = int(best_params["min_samples_split"])
    best_params["min_samples_leaf"] = int(best_params["min_samples_leaf"])

    best_params = space_eval(space, best_params)

    # to json
    with open(params_json_path, 'w') as json_file:
        json.dump(best_params, json_file)

    return best_params


# main
protein_column,  substrate_column = 'prott5', 'molebert'
label_name = 'logkcatkm'
random_state = 66
search_max_evals = 60

df_input = pd.read_pickle(f'{current_dir}/../../data_process/dataset/df_all_log_transformed.pkl')
df_train_val, df_test = train_test_split(df_input, test_size=0.2, random_state=random_state)
kf = KFold(n_splits=5, shuffle=True, random_state=random_state)

# save results
results = []
cv_results = []
input_model = 'eta'

use_t_ph_embedding = True
use_mw_logp = True

val_scores_list = []
test_scores_list = []

# search best params
params_json_path = f'{current_dir}/model_dict/{input_model}_params.json'
if os.path.exists(params_json_path):
    with open(params_json_path) as json_file:
        params = json.load(json_file)
else:
    params = search_best_param(search_max_evals)

# train
_params = deepcopy(params)
_params["n_estimators"] = int(_params["n_estimators"])
_params["max_depth"] = int(_params["max_depth"])
_params["min_samples_split"] = int(_params["min_samples_split"])
_params["min_samples_leaf"] = int(_params["min_samples_leaf"])

for fold, (train_index, val_index) in enumerate(kf.split(df_train_val), start=1):
    print(f"Fold: {fold}/5")
    df_train = df_train_val.iloc[train_index]
    df_val = df_train_val.iloc[val_index]

    train_x, train_y = return_x_y(df_train)
    val_x, val_y = return_x_y(df_val)
    test_x, test_y = return_x_y(df_test)

    # train
    model = ExtraTreesRegressor(**_params, random_state=random_state, n_jobs=-1)
    model.fit(train_x, train_y)

    # val
    val_predicted = model.predict(val_x)
    val_scores = return_scores(val_y, val_predicted)
    val_scores_list.append(val_scores)

    # test
    test_predicted = model.predict(test_x)
    test_scores = return_scores(test_y, test_predicted)
    test_scores_list.append(test_scores)

    # fold
    cv_results.append([
        fold,
        val_scores[0], val_scores[1], val_scores[2], val_scores[3],
        test_scores[0], test_scores[1], test_scores[2], test_scores[3]
    ])

# mean
val_scores_mean = np.mean(val_scores_list, axis=0)
test_scores_mean = np.mean(test_scores_list, axis=0)
print(f"Dimension of x: {train_x.shape[1]}")
print(f"[Val] rmse {val_scores_mean[0]:.4f} mae {val_scores_mean[1]:.4f} r2 {val_scores_mean[2]:.4f} pcc {val_scores_mean[3]:.4f} "
      f"[Test] rmse {test_scores_mean[0]:.4f} mae {test_scores_mean[1]:.4f} r2 {test_scores_mean[2]:.4f} pcc {test_scores_mean[3]:.4f}\n")

# save cvs
df_cv_results = pd.DataFrame(cv_results, columns=[
    "Fold",
    "Val_RMSE", "Val_MAE", "Val_R2", "Val_PCC",
    "Test_RMSE", "Test_MAE", "Test_R2", "Test_PCC"])
df_cv_results.to_excel(f"{current_dir}/results/{input_model}_cv_results.xlsx", index=False)
print("Results saved")
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# [Info] Starting parameter search...
# {'max_depth': 15, 'max_features': 0.6752909947391166, 'min_samples_leaf': 8, 'min_samples_split': 18, 'n_estimators': 98}
# [Val_mean] rmse 2.909 mae 2.197 r2 0.510 pcc 0.726
# {'max_depth': 13, 'max_features': 0.9588932649357096, 'min_samples_leaf': 16, 'min_samples_split': 7, 'n_estimators': 106}
# [Val_mean] rmse 3.066 mae 2.342 r2 0.456 pcc 0.697
# {'max_depth': 14, 'max_features': 0.6210520146355192, 'min_samples_leaf': 17, 'min_samples_split': 4, 'n_estimators': 200}
# [Val_mean] rmse 3.055 mae 2.327 r2 0.459 pcc 0.699
# {'max_depth': 18, 'max_features': 0.7233029402755917, 'min_samples_leaf': 11, 'min_samples_split': 17, 'n_estimators': 55}
# [Val_mean] rmse 2.892 mae 2.166 r2 0.515 pcc 0.726
# {'max_depth': 13, 'max_features': 0.7620667943551569, 'min_samples_leaf': 12, 'min_samples_split': 17, 'n_estimators': 106}
# [Val_mean] rmse 3.033 mae 2.316 r2 0.467 pcc 0.705
# {'max_depth': 11, 'max_features': 0.9789681484061228, 'min_samples_leaf': 19, 'min_samples_split': 8, 'n_estimators': 245}
# [Val_mean] rmse 3.196 mae 2.464 r2 0.408 pcc 0.673
# {'max_depth': 6, 'max_features': 0.8278294244311557, 'min_samples_leaf': 17, 'min_samples_split': 9, 'n_estimators': 17}
# [Val_mean] rmse 3.712 mae 2.916 r2 0.202 pcc 0.499
# {'max_depth': 19, 'max_features': 0.7490607257500876, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 240}
# [Val_mean] rmse 2.756 mae 2.026 r2 0.560 pcc 0.751
# {'max_depth': 5, 'max_features': 0.8453985797390707, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 196}
# [Val_mean] rmse 3.790 mae 2.992 r2 0.168 pcc 0.473
# {'max_depth': 6, 'max_features': 0.9133048805865763, 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 31}
# [Val_mean] rmse 3.706 mae 2.913 r2 0.205 pcc 0.506
# {'max_depth': 11, 'max_features': 0.6449414756227202, 'min_samples_leaf': 17, 'min_samples_split': 15, 'n_estimators': 220}
# [Val_mean] rmse 3.220 mae 2.485 r2 0.400 pcc 0.668
# {'max_depth': 9, 'max_features': 0.7240424840772799, 'min_samples_leaf': 5, 'min_samples_split': 18, 'n_estimators': 123}
# [Val_mean] rmse 3.355 mae 2.627 r2 0.348 pcc 0.637
# {'max_depth': 7, 'max_features': 0.5291431011926819, 'min_samples_leaf': 8, 'min_samples_split': 14, 'n_estimators': 160}
# [Val_mean] rmse 3.605 mae 2.834 r2 0.247 pcc 0.556
# {'max_depth': 12, 'max_features': 0.9322769624738968, 'min_samples_leaf': 17, 'min_samples_split': 12, 'n_estimators': 93}
# [Val_mean] rmse 3.128 mae 2.398 r2 0.433 pcc 0.685
# {'max_depth': 18, 'max_features': 0.6442526274002445, 'min_samples_leaf': 11, 'min_samples_split': 10, 'n_estimators': 246}
# [Val_mean] rmse 2.888 mae 2.164 r2 0.517 pcc 0.728
# {'max_depth': 7, 'max_features': 0.7778074837226323, 'min_samples_leaf': 10, 'min_samples_split': 9, 'n_estimators': 15}
# [Val_mean] rmse 3.598 mae 2.825 r2 0.250 pcc 0.547
# {'max_depth': 9, 'max_features': 0.9191748808929976, 'min_samples_leaf': 14, 'min_samples_split': 14, 'n_estimators': 196}
# [Val_mean] rmse 3.360 mae 2.616 r2 0.346 pcc 0.635
# {'max_depth': 17, 'max_features': 0.9799261760830144, 'min_samples_leaf': 9, 'min_samples_split': 3, 'n_estimators': 47}
# [Val_mean] rmse 2.863 mae 2.137 r2 0.525 pcc 0.731
# {'max_depth': 15, 'max_features': 0.9120059208628686, 'min_samples_leaf': 6, 'min_samples_split': 19, 'n_estimators': 73}
# [Val_mean] rmse 2.897 mae 2.183 r2 0.514 pcc 0.728
# {'max_depth': 7, 'max_features': 0.9727490640276835, 'min_samples_leaf': 11, 'min_samples_split': 15, 'n_estimators': 171}
# [Val_mean] rmse 3.575 mae 2.807 r2 0.260 pcc 0.566
# {'max_depth': 17, 'max_features': 0.5327221914515226, 'min_samples_leaf': 9, 'min_samples_split': 3, 'n_estimators': 240}
# [Val_mean] rmse 2.874 mae 2.153 r2 0.521 pcc 0.731
# {'max_depth': 19, 'max_features': 0.8467185132425294, 'min_samples_leaf': 9, 'min_samples_split': 5, 'n_estimators': 47}
# [Val_mean] rmse 2.842 mae 2.114 r2 0.532 pcc 0.734
# {'max_depth': 19, 'max_features': 0.8380722118569156, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 137}
# [Val_mean] rmse 2.712 mae 1.972 r2 0.574 pcc 0.759
# {'max_depth': 19, 'max_features': 0.7970279511376659, 'min_samples_leaf': 1, 'min_samples_split': 11, 'n_estimators': 29}
# [Val_mean] rmse 2.753 mae 2.022 r2 0.561 pcc 0.750
# {'max_depth': 19, 'max_features': 0.8029520566253168, 'min_samples_leaf': 1, 'min_samples_split': 13, 'n_estimators': 25}
# [Val_mean] rmse 2.763 mae 2.030 r2 0.558 pcc 0.748
# {'max_depth': 16, 'max_features': 0.8796456778617293, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 29}
# [Val_mean] rmse 2.783 mae 2.067 r2 0.551 pcc 0.746
# {'max_depth': 8, 'max_features': 0.584915571110229, 'min_samples_leaf': 1, 'min_samples_split': 16, 'n_estimators': 151}
# [Val_mean] rmse 3.473 mae 2.732 r2 0.302 pcc 0.604
# {'max_depth': 10, 'max_features': 0.6961871142974903, 'min_samples_leaf': 7, 'min_samples_split': 11, 'n_estimators': 208}
# [Val_mean] rmse 3.236 mae 2.518 r2 0.394 pcc 0.667
# {'max_depth': 19, 'max_features': 0.8772604779142636, 'min_samples_leaf': 13, 'min_samples_split': 11, 'n_estimators': 119}
# [Val_mean] rmse 2.906 mae 2.178 r2 0.511 pcc 0.723
# {'max_depth': 19, 'max_features': 0.7908794304987108, 'min_samples_leaf': 15, 'min_samples_split': 5, 'n_estimators': 126}
# [Val_mean] rmse 2.942 mae 2.212 r2 0.499 pcc 0.717
# {'max_depth': 8, 'max_features': 0.8763592700011997, 'min_samples_leaf': 3, 'min_samples_split': 11, 'n_estimators': 258}
# [Val_mean] rmse 3.442 mae 2.708 r2 0.314 pcc 0.613
# {'max_depth': 14, 'max_features': 0.685957618929295, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 37}
# [Val_mean] rmse 2.901 mae 2.193 r2 0.513 pcc 0.728
# {'max_depth': 19, 'max_features': 0.8177577297058746, 'min_samples_leaf': 18, 'min_samples_split': 6, 'n_estimators': 82}
# [Val_mean] rmse 2.987 mae 2.258 r2 0.483 pcc 0.709
# {'max_depth': 16, 'max_features': 0.7388488883262272, 'min_samples_leaf': 1, 'min_samples_split': 19, 'n_estimators': 42}
# [Val_mean] rmse 2.836 mae 2.134 r2 0.534 pcc 0.738
# {'max_depth': 13, 'max_features': 0.5973816937551466, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 86}
# [Val_mean] rmse 2.932 mae 2.245 r2 0.502 pcc 0.726
# {'max_depth': 5, 'max_features': 0.7681098441609299, 'min_samples_leaf': 12, 'min_samples_split': 5, 'n_estimators': 33}
# [Val_mean] rmse 3.809 mae 3.001 r2 0.160 pcc 0.458
# {'max_depth': 12, 'max_features': 0.7132894643351904, 'min_samples_leaf': 16, 'min_samples_split': 11, 'n_estimators': 137}
# [Val_mean] rmse 3.137 mae 2.408 r2 0.430 pcc 0.685
# {'max_depth': 10, 'max_features': 0.8491028743701758, 'min_samples_leaf': 2, 'min_samples_split': 17, 'n_estimators': 22}
# [Val_mean] rmse 3.253 mae 2.539 r2 0.387 pcc 0.658
# {'max_depth': 15, 'max_features': 0.6524179202395641, 'min_samples_leaf': 19, 'min_samples_split': 2, 'n_estimators': 255}
# [Val_mean] rmse 3.050 mae 2.322 r2 0.461 pcc 0.700
# {'max_depth': 14, 'max_features': 0.9483328573374097, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 145}
# [Val_mean] rmse 2.834 mae 2.144 r2 0.535 pcc 0.741
# {'max_depth': 19, 'max_features': 0.8244320500361544, 'min_samples_leaf': 15, 'min_samples_split': 12, 'n_estimators': 218}
# [Val_mean] rmse 2.935 mae 2.209 r2 0.501 pcc 0.719
# {'max_depth': 6, 'max_features': 0.7539255218725207, 'min_samples_leaf': 8, 'min_samples_split': 18, 'n_estimators': 79}
# [Val_mean] rmse 3.703 mae 2.915 r2 0.206 pcc 0.513
# {'max_depth': 11, 'max_features': 0.8959273487604367, 'min_samples_leaf': 18, 'min_samples_split': 16, 'n_estimators': 59}
# [Val_mean] rmse 3.204 mae 2.470 r2 0.405 pcc 0.669
# {'max_depth': 13, 'max_features': 0.8030626205092174, 'min_samples_leaf': 13, 'min_samples_split': 13, 'n_estimators': 21}
# [Val_mean] rmse 3.073 mae 2.351 r2 0.453 pcc 0.690
# {'max_depth': 18, 'max_features': 0.7225462002640447, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 163}
# [Val_mean] rmse 2.759 mae 2.035 r2 0.559 pcc 0.751
# {'max_depth': 19, 'max_features': 0.8590588534841173, 'min_samples_leaf': 14, 'min_samples_split': 7, 'n_estimators': 90}
# [Val_mean] rmse 2.927 mae 2.197 r2 0.504 pcc 0.719
# {'max_depth': 5, 'max_features': 0.9932774617448793, 'min_samples_leaf': 7, 'min_samples_split': 8, 'n_estimators': 57}
# [Val_mean] rmse 3.785 mae 2.987 r2 0.170 pcc 0.473
# {'max_depth': 9, 'max_features': 0.5589109720771129, 'min_samples_leaf': 6, 'min_samples_split': 9, 'n_estimators': 275}
# [Val_mean] rmse 3.360 mae 2.629 r2 0.346 pcc 0.637
# {'max_depth': 12, 'max_features': 0.7726468093706116, 'min_samples_leaf': 5, 'min_samples_split': 17, 'n_estimators': 100}
# [Val_mean] rmse 3.051 mae 2.348 r2 0.461 pcc 0.704
# {'max_depth': 6, 'max_features': 0.9382983150893073, 'min_samples_leaf': 10, 'min_samples_split': 14, 'n_estimators': 61}
# [Val_mean] rmse 3.695 mae 2.907 r2 0.209 pcc 0.515
# {'max_depth': 17, 'max_features': 0.7031455242010329, 'min_samples_leaf': 3, 'min_samples_split': 15, 'n_estimators': 271}
# [Val_mean] rmse 2.791 mae 2.078 r2 0.549 pcc 0.746
# {'max_depth': 19, 'max_features': 0.6287710553236182, 'min_samples_leaf': 12, 'min_samples_split': 6, 'n_estimators': 172}
# [Val_mean] rmse 2.900 mae 2.172 r2 0.513 pcc 0.725
# {'max_depth': 11, 'max_features': 0.6664379902090773, 'min_samples_leaf': 16, 'min_samples_split': 2, 'n_estimators': 214}
# [Val_mean] rmse 3.205 mae 2.473 r2 0.405 pcc 0.672
# {'max_depth': 18, 'max_features': 0.5015945714907404, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 40}
# [Val_mean] rmse 2.743 mae 2.011 r2 0.564 pcc 0.752
# {'max_depth': 18, 'max_features': 0.5543417850874881, 'min_samples_leaf': 17, 'min_samples_split': 5, 'n_estimators': 14}
# [Val_mean] rmse 3.031 mae 2.292 r2 0.468 pcc 0.695
# {'max_depth': 18, 'max_features': 0.6175720716444799, 'min_samples_leaf': 19, 'min_samples_split': 5, 'n_estimators': 137}
# [Val_mean] rmse 3.016 mae 2.285 r2 0.473 pcc 0.704
# {'max_depth': 18, 'max_features': 0.5114164016808483, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 40}
# [Val_mean] rmse 2.758 mae 2.028 r2 0.560 pcc 0.750
# {'max_depth': 7, 'max_features': 0.9037778973370477, 'min_samples_leaf': 11, 'min_samples_split': 3, 'n_estimators': 103}
# [Val_mean] rmse 3.587 mae 2.816 r2 0.255 pcc 0.560
# {'max_depth': 18, 'max_features': 0.7423854216182189, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 132}
# [Val_mean] rmse 2.721 mae 1.991 r2 0.571 pcc 0.757
# {'max_depth': 15, 'max_features': 0.7380814502548023, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 132}
# [Val_mean] rmse 2.893 mae 2.180 r2 0.515 pcc 0.729
# 100%|██████████| 60/60 [53:15<00:00, 53.26s/trial, best loss: 2.7115674533667034]
# Fold: 1/5
# Fold: 2/5
# Fold: 3/5
# Fold: 4/5
# Fold: 5/5
# Dimension of x: 1328
# [Val] rmse 2.7116 mae 1.9724 r2 0.5741 pcc 0.7585 [Test] rmse 2.7622 mae 2.0081 r2 0.5520 pcc 0.7431
#
# Results saved
