# %% [markdown]
# # LightGBM

# %%
import os.path
import json
import pandas as pd
import lightgbm as lgb
import numpy as np
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from scipy.stats import pearsonr
from hyperopt import fmin, tpe, hp, Trials
from copy import deepcopy
import warnings
warnings.filterwarnings("ignore")
current_dir = os.getcwd()


def return_scores(y_true, y_pred):
    y_true = np.array(y_true).ravel()
    y_pred = np.array(y_pred).ravel()
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    pcc = pearsonr(y_true, y_pred)[0]
    return rmse, mae, r2, pcc

def return_x_y(df_filtered):
    y = df_filtered[label_name].values
    mask = ~np.isnan(y)

    # factors
    auxiliary_data = []
    if use_t_ph_embedding:
        ph = df_filtered['ph'].values.reshape(-1, 1)
        t = df_filtered['t'].values.reshape(-1, 1)
        auxiliary_data.append(ph)
        auxiliary_data.append(t)

    if use_mw_logp:
        mw = df_filtered['mw'].values.reshape(-1, 1)
        logp = df_filtered['logp'].values.reshape(-1, 1)
        auxiliary_data.append(mw)
        auxiliary_data.append(logp)

    protein_data = np.array(df_filtered[protein_column].tolist())
    substrate_data = np.array(df_filtered[substrate_column].tolist())
    x = np.hstack([protein_data, substrate_data] + auxiliary_data)

    return x[mask], y[mask]

def search_params(params):
    print(params)
    temp_params = deepcopy(params)
    temp_params.update({"device": "gpu", "gpu_platform_id": 0, "gpu_device_id": 0,
                        "verbosity": -1, "objective": "regression", "metric": ["rmse"]})
    num_rounds = temp_params.pop("num_iterations")

    val_scores_list = []
    for train_index, val_index in kf.split(df_train_val):
        df_train = df_train_val.iloc[train_index]
        df_val = df_train_val.iloc[val_index]

        train_x, train_y = return_x_y(df_train)
        val_x, val_y = return_x_y(df_val)

        # LightGBM Dataset
        train_data = lgb.Dataset(train_x, label=train_y)
        val_data = lgb.Dataset(val_x, label=val_y, reference=train_data)

        # LightGBM Regressor
        model = lgb.train(temp_params, train_data, num_rounds, valid_sets=[val_data], callbacks=[
            lgb.early_stopping(stopping_rounds=60)#, lgb.log_evaluation(period=100)
        ])

        # predict
        val_predicted = model.predict(val_x)
        val_scores = return_scores(val_y, val_predicted)
        val_scores_list.append(val_scores)

    val_scores_mean = np.mean(val_scores_list, axis=0)
    print(f"[Val_mean] rmse {val_scores_mean[0]:.3f} mae {val_scores_mean[1]:.3f} r2 {val_scores_mean[2]:.3f} pcc {val_scores_mean[3]:.3f}")

    return val_scores_mean[0]

def search_best_param(max_evals):
    space = {
        "learning_rate": hp.uniform("learning_rate", 0.01, 0.1),
        "max_depth": hp.randint("max_depth", 6, 10),
        "num_leaves": hp.randint("num_leaves", 20, 100),
        "min_data_in_leaf": hp.randint("min_data_in_leaf", 10, 30),
        "lambda_l1": hp.uniform("lambda_l1", 0, 1),
        "lambda_l2": hp.uniform("lambda_l2", 0, 1),
        "feature_fraction": hp.uniform("feature_fraction", 0.6, 1),
        "bagging_fraction": hp.uniform("bagging_fraction", 0.6, 1),
        "num_iterations": hp.randint("num_iterations", 1000, 3000),
    }

    trials = Trials()
    print(f'[Info] Starting parameter search...')
    best_params = fmin(fn=search_params, space=space, algo=tpe.suggest, max_evals=max_evals, trials=trials)

    best_params['max_depth'] = int(best_params['max_depth'])
    best_params['num_leaves'] = int(best_params['num_leaves'])
    best_params['num_iterations'] = int(best_params['num_iterations'])
    best_params['min_data_in_leaf'] = int(best_params['min_data_in_leaf'])

    # to json
    with open(params_json_path, 'w') as json_file:
        json.dump(best_params, json_file)

    return best_params


# main
protein_column,  substrate_column = 'prott5', 'molebert'
label_name = 'logkcatkm'
random_state = 66
search_max_evals = 60

df_input = pd.read_pickle(f'{current_dir}/../../data_process/dataset/df_all_log_transformed.pkl')
df_train_val, df_test = train_test_split(df_input, test_size=0.2, random_state=random_state)
kf = KFold(n_splits=5, shuffle=True, random_state=random_state)

# save results
results = []
cv_results = []
input_model = 'lgm'

use_t_ph_embedding = True
use_mw_logp = True

val_scores_list = []
test_scores_list = []

# search best params
params_json_path = f'{current_dir}/model_dict/{input_model}_params.json'
if os.path.exists(params_json_path):
    with open(params_json_path) as json_file:
        params = json.load(json_file)
else:
    params = search_best_param(search_max_evals)

# train
_params = deepcopy(params)
_params.update({"device": "gpu", "gpu_platform_id": 0, "gpu_device_id": 0,
                        "verbosity": -1, "objective": "regression", "metric": ["rmse"]})
num_rounds = _params.pop("num_iterations")

for fold, (train_index, val_index) in enumerate(kf.split(df_train_val), start=1):
    print(f"Fold: {fold}/5")
    df_train = df_train_val.iloc[train_index]
    df_val = df_train_val.iloc[val_index]

    train_x, train_y = return_x_y(df_train)
    val_x, val_y = return_x_y(df_val)
    test_x, test_y = return_x_y(df_test)

    # LightGBM Dataset
    train_data = lgb.Dataset(train_x, label=train_y)
    val_data = lgb.Dataset(val_x, label=val_y, reference=train_data)

    # LightGBM Regressor
    model = lgb.train(_params, train_data, num_rounds, valid_sets=[val_data], callbacks=[
        lgb.early_stopping(stopping_rounds=60), lgb.log_evaluation(period=500)
    ])

    # predict
    val_predicted = model.predict(val_x)
    val_scores = return_scores(val_y, val_predicted)
    val_scores_list.append(val_scores)

    # predict
    test_predicted = model.predict(test_x)
    test_scores = return_scores(test_y, test_predicted)
    test_scores_list.append(test_scores)

    # fold
    cv_results.append([
        fold,
        val_scores[0], val_scores[1], val_scores[2], val_scores[3],
        test_scores[0], test_scores[1], test_scores[2], test_scores[3]
    ])

# mean
val_scores_mean = np.mean(val_scores_list, axis=0)
test_scores_mean = np.mean(test_scores_list, axis=0)
print(f"Dimension of x: {train_x.shape[1]}")
print(f"[Val] rmse {val_scores_mean[0]:.4f} mae {val_scores_mean[1]:.4f} r2 {val_scores_mean[2]:.4f} pcc {val_scores_mean[3]:.4f} "
      f"[Test] rmse {test_scores_mean[0]:.4f} mae {test_scores_mean[1]:.4f} r2 {test_scores_mean[2]:.4f} pcc {test_scores_mean[3]:.4f}\n")

# save cvs
df_cv_results = pd.DataFrame(cv_results, columns=[
    "Fold",
    "Val_RMSE", "Val_MAE", "Val_R2", "Val_PCC",
    "Test_RMSE", "Test_MAE", "Test_R2", "Test_PCC"])
df_cv_results.to_excel(f"{current_dir}/results/{input_model}_cv_results.xlsx", index=False)
print("Results saved")
# Out:
# [Info] Starting parameter search...
# {'bagging_fraction': 0.684038036638882, 'feature_fraction': 0.6377110418450845, 'lambda_l1': 0.6818439433538236, 'lambda_l2': 0.48412928004619604, 'learning_rate': 0.0498887866101942, 'max_depth': 9, 'min_data_in_leaf': 17, 'num_iterations': 1580, 'num_leaves': 67}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [823]	valid_0's rmse: 2.67927
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [876]	valid_0's rmse: 2.62193
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1003]	valid_0's rmse: 2.57512
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [977]	valid_0's rmse: 2.65803
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [776]	valid_0's rmse: 2.61127
# [Val_mean] rmse 2.629 mae 1.878 r2 0.600 pcc 0.775
# {'bagging_fraction': 0.9486669677920103, 'feature_fraction': 0.9586505511429898, 'lambda_l1': 0.43673299246309893, 'lambda_l2': 0.8177227497015461, 'learning_rate': 0.08607709722083333, 'max_depth': 8, 'min_data_in_leaf': 21, 'num_iterations': 2929, 'num_leaves': 98}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [676]	valid_0's rmse: 2.69846
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [627]	valid_0's rmse: 2.65138
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [766]	valid_0's rmse: 2.59537
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [481]	valid_0's rmse: 2.65709
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [597]	valid_0's rmse: 2.6307
# [Val_mean] rmse 2.647 mae 1.891 r2 0.594 pcc 0.772
# {'bagging_fraction': 0.9236047789333983, 'feature_fraction': 0.9563811811753185, 'lambda_l1': 0.4126300390440225, 'lambda_l2': 0.866187635567258, 'learning_rate': 0.02037724028496482, 'max_depth': 6, 'min_data_in_leaf': 15, 'num_iterations': 2863, 'num_leaves': 60}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [2538]	valid_0's rmse: 2.70108
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2819]	valid_0's rmse: 2.62046
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2858]	valid_0's rmse: 2.58266
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2856]	valid_0's rmse: 2.64697
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [2675]	valid_0's rmse: 2.6278
# [Val_mean] rmse 2.636 mae 1.906 r2 0.598 pcc 0.774
# {'bagging_fraction': 0.692027719703629, 'feature_fraction': 0.686142073546408, 'lambda_l1': 0.9652102728165617, 'lambda_l2': 0.577381582383374, 'learning_rate': 0.04380514892524963, 'max_depth': 7, 'min_data_in_leaf': 10, 'num_iterations': 1523, 'num_leaves': 30}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1481]	valid_0's rmse: 2.69696
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1437]	valid_0's rmse: 2.61745
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1523]	valid_0's rmse: 2.57487
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1522]	valid_0's rmse: 2.65643
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1519]	valid_0's rmse: 2.64248
# [Val_mean] rmse 2.638 mae 1.901 r2 0.597 pcc 0.773
# {'bagging_fraction': 0.8512252621802969, 'feature_fraction': 0.698040205969855, 'lambda_l1': 0.7789233551251711, 'lambda_l2': 0.9753122913609954, 'learning_rate': 0.09274500376183256, 'max_depth': 7, 'min_data_in_leaf': 18, 'num_iterations': 2140, 'num_leaves': 44}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [634]	valid_0's rmse: 2.68438
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [622]	valid_0's rmse: 2.61829
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [918]	valid_0's rmse: 2.58527
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [891]	valid_0's rmse: 2.66393
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [862]	valid_0's rmse: 2.6297
# [Val_mean] rmse 2.636 mae 1.883 r2 0.597 pcc 0.774
# {'bagging_fraction': 0.611989914082956, 'feature_fraction': 0.7822330552958869, 'lambda_l1': 0.9359597872158381, 'lambda_l2': 0.13269583134787388, 'learning_rate': 0.04531359924357284, 'max_depth': 7, 'min_data_in_leaf': 29, 'num_iterations': 2268, 'num_leaves': 72}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1740]	valid_0's rmse: 2.67638
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1372]	valid_0's rmse: 2.61667
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1712]	valid_0's rmse: 2.57769
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1758]	valid_0's rmse: 2.63989
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1549]	valid_0's rmse: 2.62209
# [Val_mean] rmse 2.627 mae 1.877 r2 0.600 pcc 0.776
# {'bagging_fraction': 0.8885157803330368, 'feature_fraction': 0.9191002128975548, 'lambda_l1': 0.1612114231626115, 'lambda_l2': 0.7259799802352819, 'learning_rate': 0.06420550897041458, 'max_depth': 7, 'min_data_in_leaf': 18, 'num_iterations': 2410, 'num_leaves': 43}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1198]	valid_0's rmse: 2.69826
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [882]	valid_0's rmse: 2.62846
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [869]	valid_0's rmse: 2.58885
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1256]	valid_0's rmse: 2.65016
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [916]	valid_0's rmse: 2.62339
# [Val_mean] rmse 2.638 mae 1.893 r2 0.597 pcc 0.774
# {'bagging_fraction': 0.7007433031093441, 'feature_fraction': 0.9367789106720724, 'lambda_l1': 0.2905707358885812, 'lambda_l2': 0.5565289778925866, 'learning_rate': 0.09973986433149104, 'max_depth': 8, 'min_data_in_leaf': 12, 'num_iterations': 1414, 'num_leaves': 78}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [532]	valid_0's rmse: 2.71766
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [424]	valid_0's rmse: 2.63895
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [535]	valid_0's rmse: 2.60165
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [598]	valid_0's rmse: 2.66024
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [386]	valid_0's rmse: 2.64267
# [Val_mean] rmse 2.652 mae 1.895 r2 0.593 pcc 0.771
# {'bagging_fraction': 0.632157022167891, 'feature_fraction': 0.6168446071138997, 'lambda_l1': 0.9680264291267072, 'lambda_l2': 0.5518892112303707, 'learning_rate': 0.015006751899495237, 'max_depth': 6, 'min_data_in_leaf': 10, 'num_iterations': 1124, 'num_leaves': 20}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1124]	valid_0's rmse: 2.94085
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1124]	valid_0's rmse: 2.83161
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1124]	valid_0's rmse: 2.84513
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1124]	valid_0's rmse: 2.88273
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1124]	valid_0's rmse: 2.87363
# [Val_mean] rmse 2.875 mae 2.191 r2 0.521 pcc 0.729
# {'bagging_fraction': 0.7780704972336411, 'feature_fraction': 0.6994029560761551, 'lambda_l1': 0.05148462654518393, 'lambda_l2': 0.7689525547293022, 'learning_rate': 0.03518487861548579, 'max_depth': 6, 'min_data_in_leaf': 20, 'num_iterations': 1827, 'num_leaves': 87}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1825]	valid_0's rmse: 2.68718
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1822]	valid_0's rmse: 2.61387
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1827]	valid_0's rmse: 2.59988
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1827]	valid_0's rmse: 2.65163
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1827]	valid_0's rmse: 2.62223
# [Val_mean] rmse 2.635 mae 1.904 r2 0.598 pcc 0.774
# {'bagging_fraction': 0.60992589423855, 'feature_fraction': 0.7356149941917025, 'lambda_l1': 0.003727810567211276, 'lambda_l2': 0.23316278976987803, 'learning_rate': 0.09283813457058983, 'max_depth': 6, 'min_data_in_leaf': 15, 'num_iterations': 1126, 'num_leaves': 64}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1038]	valid_0's rmse: 2.70223
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [820]	valid_0's rmse: 2.65175
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [885]	valid_0's rmse: 2.59867
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1001]	valid_0's rmse: 2.6465
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [831]	valid_0's rmse: 2.6285
# [Val_mean] rmse 2.646 mae 1.901 r2 0.595 pcc 0.772
# {'bagging_fraction': 0.7214267614099461, 'feature_fraction': 0.9152659977202093, 'lambda_l1': 0.029503612676699986, 'lambda_l2': 0.4301768731019071, 'learning_rate': 0.04284125395139645, 'max_depth': 7, 'min_data_in_leaf': 27, 'num_iterations': 2316, 'num_leaves': 56}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1722]	valid_0's rmse: 2.68664
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1397]	valid_0's rmse: 2.62117
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1988]	valid_0's rmse: 2.58006
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2288]	valid_0's rmse: 2.63755
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1843]	valid_0's rmse: 2.62575
# [Val_mean] rmse 2.630 mae 1.884 r2 0.599 pcc 0.775
# {'bagging_fraction': 0.6683998542089882, 'feature_fraction': 0.8354860070864546, 'lambda_l1': 0.11746493834298177, 'lambda_l2': 0.5433412440759462, 'learning_rate': 0.02943601508247952, 'max_depth': 9, 'min_data_in_leaf': 12, 'num_iterations': 2734, 'num_leaves': 21}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2734]	valid_0's rmse: 2.70187
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2734]	valid_0's rmse: 2.63068
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2734]	valid_0's rmse: 2.5887
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2709]	valid_0's rmse: 2.65933
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2733]	valid_0's rmse: 2.62556
# [Val_mean] rmse 2.641 mae 1.908 r2 0.596 pcc 0.772
# {'bagging_fraction': 0.6240605374830898, 'feature_fraction': 0.8197954402240459, 'lambda_l1': 0.2619778711038475, 'lambda_l2': 0.795609186914337, 'learning_rate': 0.0575687161121813, 'max_depth': 6, 'min_data_in_leaf': 27, 'num_iterations': 1196, 'num_leaves': 61}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1196]	valid_0's rmse: 2.69722
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1181]	valid_0's rmse: 2.62202
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1196]	valid_0's rmse: 2.59837
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1196]	valid_0's rmse: 2.66189
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1196]	valid_0's rmse: 2.6363
# [Val_mean] rmse 2.643 mae 1.913 r2 0.595 pcc 0.772
# {'bagging_fraction': 0.6314587999328848, 'feature_fraction': 0.7384920408059044, 'lambda_l1': 0.647745088412085, 'lambda_l2': 0.45298925184025185, 'learning_rate': 0.011873233070369065, 'max_depth': 6, 'min_data_in_leaf': 29, 'num_iterations': 2633, 'num_leaves': 34}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2633]	valid_0's rmse: 2.75052
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2632]	valid_0's rmse: 2.65705
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2633]	valid_0's rmse: 2.65574
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2633]	valid_0's rmse: 2.72183
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2633]	valid_0's rmse: 2.69567
# [Val_mean] rmse 2.696 mae 1.991 r2 0.579 pcc 0.762
# {'bagging_fraction': 0.7035430034505914, 'feature_fraction': 0.8421972943731129, 'lambda_l1': 0.9795639990485785, 'lambda_l2': 0.24969874972219153, 'learning_rate': 0.06225233716621996, 'max_depth': 7, 'min_data_in_leaf': 25, 'num_iterations': 2843, 'num_leaves': 99}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1038]	valid_0's rmse: 2.69985
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [864]	valid_0's rmse: 2.63591
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1017]	valid_0's rmse: 2.59544
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1032]	valid_0's rmse: 2.65238
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1138]	valid_0's rmse: 2.61482
# [Val_mean] rmse 2.640 mae 1.890 r2 0.596 pcc 0.773
# {'bagging_fraction': 0.9461878720033422, 'feature_fraction': 0.8017389505411395, 'lambda_l1': 0.22008392913716757, 'lambda_l2': 0.40010528165927906, 'learning_rate': 0.08975921837641834, 'max_depth': 7, 'min_data_in_leaf': 18, 'num_iterations': 2798, 'num_leaves': 21}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1269]	valid_0's rmse: 2.72096
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1376]	valid_0's rmse: 2.62684
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1195]	valid_0's rmse: 2.58702
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1186]	valid_0's rmse: 2.67453
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1074]	valid_0's rmse: 2.6277
# [Val_mean] rmse 2.647 mae 1.903 r2 0.594 pcc 0.772
# {'bagging_fraction': 0.7526597686400297, 'feature_fraction': 0.7824526219477089, 'lambda_l1': 0.035927029663330945, 'lambda_l2': 0.9058606169474641, 'learning_rate': 0.04622917271191143, 'max_depth': 9, 'min_data_in_leaf': 26, 'num_iterations': 2726, 'num_leaves': 23}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [2011]	valid_0's rmse: 2.69867
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1657]	valid_0's rmse: 2.63189
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [2159]	valid_0's rmse: 2.57729
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [2020]	valid_0's rmse: 2.6511
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [2344]	valid_0's rmse: 2.63028
# [Val_mean] rmse 2.638 mae 1.899 r2 0.597 pcc 0.774
# {'bagging_fraction': 0.6787885945202844, 'feature_fraction': 0.8309964691847581, 'lambda_l1': 0.9213327926375434, 'lambda_l2': 0.9590829007184449, 'learning_rate': 0.09467725778295195, 'max_depth': 6, 'min_data_in_leaf': 10, 'num_iterations': 2029, 'num_leaves': 42}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [784]	valid_0's rmse: 2.69079
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [665]	valid_0's rmse: 2.64561
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [961]	valid_0's rmse: 2.58382
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [758]	valid_0's rmse: 2.65701
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [620]	valid_0's rmse: 2.63419
# [Val_mean] rmse 2.642 mae 1.897 r2 0.596 pcc 0.773
# {'bagging_fraction': 0.9048829501421591, 'feature_fraction': 0.6446177578030619, 'lambda_l1': 0.8047184260615511, 'lambda_l2': 0.9995521225962675, 'learning_rate': 0.03423507088938512, 'max_depth': 9, 'min_data_in_leaf': 23, 'num_iterations': 1383, 'num_leaves': 27}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1383]	valid_0's rmse: 2.71032
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1367]	valid_0's rmse: 2.6447
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1383]	valid_0's rmse: 2.61265
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1383]	valid_0's rmse: 2.68291
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1383]	valid_0's rmse: 2.64698
# [Val_mean] rmse 2.660 mae 1.940 r2 0.590 pcc 0.769
# {'bagging_fraction': 0.7991808489832297, 'feature_fraction': 0.6052059256569156, 'lambda_l1': 0.5891125467479253, 'lambda_l2': 0.0147601101030439, 'learning_rate': 0.07459341440718412, 'max_depth': 9, 'min_data_in_leaf': 17, 'num_iterations': 2995, 'num_leaves': 75}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [602]	valid_0's rmse: 2.69904
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [442]	valid_0's rmse: 2.63384
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [621]	valid_0's rmse: 2.56597
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [754]	valid_0's rmse: 2.66207
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [541]	valid_0's rmse: 2.62815
# [Val_mean] rmse 2.638 mae 1.885 r2 0.597 pcc 0.774
# {'bagging_fraction': 0.6486512842989625, 'feature_fraction': 0.8849032460936621, 'lambda_l1': 0.7893199844720249, 'lambda_l2': 0.015930366758302603, 'learning_rate': 0.07283914979425213, 'max_depth': 9, 'min_data_in_leaf': 22, 'num_iterations': 1782, 'num_leaves': 94}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [564]	valid_0's rmse: 2.71199
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [535]	valid_0's rmse: 2.63662
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [852]	valid_0's rmse: 2.58034
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [787]	valid_0's rmse: 2.65426
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [572]	valid_0's rmse: 2.63291
# [Val_mean] rmse 2.643 mae 1.884 r2 0.595 pcc 0.773
# {'bagging_fraction': 0.9910767184637833, 'feature_fraction': 0.9992707064614718, 'lambda_l1': 0.6569486255605748, 'lambda_l2': 0.13765710817790622, 'learning_rate': 0.050084725520772526, 'max_depth': 8, 'min_data_in_leaf': 13, 'num_iterations': 2512, 'num_leaves': 72}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1037]	valid_0's rmse: 2.69387
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [820]	valid_0's rmse: 2.63138
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1117]	valid_0's rmse: 2.58252
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [907]	valid_0's rmse: 2.65428
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [750]	valid_0's rmse: 2.63095
# [Val_mean] rmse 2.639 mae 1.884 r2 0.597 pcc 0.774
# {'bagging_fraction': 0.741315084612916, 'feature_fraction': 0.7516866538915858, 'lambda_l1': 0.8856798356820259, 'lambda_l2': 0.31251199122981266, 'learning_rate': 0.023683643535110866, 'max_depth': 9, 'min_data_in_leaf': 17, 'num_iterations': 2319, 'num_leaves': 32}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2319]	valid_0's rmse: 2.69019
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2316]	valid_0's rmse: 2.60754
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2316]	valid_0's rmse: 2.5857
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2318]	valid_0's rmse: 2.65677
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2304]	valid_0's rmse: 2.63731
# [Val_mean] rmse 2.636 mae 1.903 r2 0.598 pcc 0.774
# {'bagging_fraction': 0.6016749514624182, 'feature_fraction': 0.6572294098840042, 'lambda_l1': 0.5513734182990874, 'lambda_l2': 0.11130243429737363, 'learning_rate': 0.054089981260579616, 'max_depth': 9, 'min_data_in_leaf': 24, 'num_iterations': 2370, 'num_leaves': 67}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [886]	valid_0's rmse: 2.68636
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [664]	valid_0's rmse: 2.634
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [815]	valid_0's rmse: 2.58159
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [985]	valid_0's rmse: 2.6381
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1000]	valid_0's rmse: 2.62059
# [Val_mean] rmse 2.632 mae 1.880 r2 0.599 pcc 0.775
# {'bagging_fraction': 0.6006086743638771, 'feature_fraction': 0.8697540145857606, 'lambda_l1': 0.7020911761476487, 'lambda_l2': 0.6498929158203524, 'learning_rate': 0.03782896523397737, 'max_depth': 7, 'min_data_in_leaf': 28, 'num_iterations': 1542, 'num_leaves': 67}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1542]	valid_0's rmse: 2.68062
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1463]	valid_0's rmse: 2.6248
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1537]	valid_0's rmse: 2.58383
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1483]	valid_0's rmse: 2.65129
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1539]	valid_0's rmse: 2.62313
# [Val_mean] rmse 2.633 mae 1.892 r2 0.598 pcc 0.775
# {'bagging_fraction': 0.842566530717102, 'feature_fraction': 0.7649098739863424, 'lambda_l1': 0.8595869589567816, 'lambda_l2': 0.3373435142917448, 'learning_rate': 0.0711393711872095, 'max_depth': 7, 'min_data_in_leaf': 16, 'num_iterations': 1888, 'num_leaves': 72}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [811]	valid_0's rmse: 2.68875
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [621]	valid_0's rmse: 2.61445
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [980]	valid_0's rmse: 2.57684
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [798]	valid_0's rmse: 2.64904
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [890]	valid_0's rmse: 2.62796
# [Val_mean] rmse 2.631 mae 1.883 r2 0.599 pcc 0.775
# {'bagging_fraction': 0.6575456068800174, 'feature_fraction': 0.6530216423829469, 'lambda_l1': 0.48973046773557555, 'lambda_l2': 0.11897118241943398, 'learning_rate': 0.0816321650069802, 'max_depth': 8, 'min_data_in_leaf': 19, 'num_iterations': 1584, 'num_leaves': 69}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [627]	valid_0's rmse: 2.67672
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [531]	valid_0's rmse: 2.65282
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [753]	valid_0's rmse: 2.58493
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [759]	valid_0's rmse: 2.66405
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [609]	valid_0's rmse: 2.6198
# [Val_mean] rmse 2.640 mae 1.888 r2 0.596 pcc 0.774
# {'bagging_fraction': 0.7408520213137961, 'feature_fraction': 0.7155545104892282, 'lambda_l1': 0.7227568417826943, 'lambda_l2': 0.6619100783805567, 'learning_rate': 0.06177378626616038, 'max_depth': 9, 'min_data_in_leaf': 11, 'num_iterations': 1259, 'num_leaves': 95}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [443]	valid_0's rmse: 2.6949
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [413]	valid_0's rmse: 2.62337
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [696]	valid_0's rmse: 2.59339
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [638]	valid_0's rmse: 2.64729
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [529]	valid_0's rmse: 2.62181
# [Val_mean] rmse 2.636 mae 1.885 r2 0.597 pcc 0.774
# {'bagging_fraction': 0.7700628125476505, 'feature_fraction': 0.6348907074442879, 'lambda_l1': 0.4294536247430075, 'lambda_l2': 0.19659486441356916, 'learning_rate': 0.028243003029388047, 'max_depth': 8, 'min_data_in_leaf': 14, 'num_iterations': 2970, 'num_leaves': 81}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1686]	valid_0's rmse: 2.68182
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [946]	valid_0's rmse: 2.62671
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1480]	valid_0's rmse: 2.58653
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1582]	valid_0's rmse: 2.64512
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1470]	valid_0's rmse: 2.60739
# [Val_mean] rmse 2.630 mae 1.885 r2 0.599 pcc 0.775
# {'bagging_fraction': 0.8282755411565544, 'feature_fraction': 0.8697504090393209, 'lambda_l1': 0.3845871424047329, 'lambda_l2': 0.338763527661161, 'learning_rate': 0.051860706755855655, 'max_depth': 7, 'min_data_in_leaf': 29, 'num_iterations': 2513, 'num_leaves': 82}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1071]	valid_0's rmse: 2.69045
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1122]	valid_0's rmse: 2.61975
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [2045]	valid_0's rmse: 2.58621
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [2032]	valid_0's rmse: 2.63678
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1577]	valid_0's rmse: 2.63081
# [Val_mean] rmse 2.633 mae 1.886 r2 0.598 pcc 0.775
# {'bagging_fraction': 0.7189062979901504, 'feature_fraction': 0.999652486900418, 'lambda_l1': 0.8557484235633842, 'lambda_l2': 0.05418522621462056, 'learning_rate': 0.04507730782769786, 'max_depth': 9, 'min_data_in_leaf': 17, 'num_iterations': 1844, 'num_leaves': 80}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [897]	valid_0's rmse: 2.683
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [731]	valid_0's rmse: 2.63174
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [998]	valid_0's rmse: 2.58902
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [971]	valid_0's rmse: 2.64368
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [789]	valid_0's rmse: 2.6192
# [Val_mean] rmse 2.633 mae 1.881 r2 0.598 pcc 0.775
# {'bagging_fraction': 0.6795425717976611, 'feature_fraction': 0.6781254249722402, 'lambda_l1': 0.5887344295621787, 'lambda_l2': 0.48706495091768487, 'learning_rate': 0.01953209668948265, 'max_depth': 7, 'min_data_in_leaf': 21, 'num_iterations': 1255, 'num_leaves': 59}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1255]	valid_0's rmse: 2.72322
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1255]	valid_0's rmse: 2.65263
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1255]	valid_0's rmse: 2.62673
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1255]	valid_0's rmse: 2.68943
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1253]	valid_0's rmse: 2.6602
# [Val_mean] rmse 2.670 mae 1.955 r2 0.587 pcc 0.767
# {'bagging_fraction': 0.8135386282697948, 'feature_fraction': 0.9709997736127425, 'lambda_l1': 0.7280653243603745, 'lambda_l2': 0.6315933672319796, 'learning_rate': 0.06700141601765378, 'max_depth': 7, 'min_data_in_leaf': 29, 'num_iterations': 2659, 'num_leaves': 35}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [993]	valid_0's rmse: 2.69186
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1039]	valid_0's rmse: 2.61665
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1372]	valid_0's rmse: 2.59413
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1453]	valid_0's rmse: 2.66031
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1215]	valid_0's rmse: 2.61656
# [Val_mean] rmse 2.636 mae 1.888 r2 0.597 pcc 0.774
# {'bagging_fraction': 0.8638753232231715, 'feature_fraction': 0.7862605244764829, 'lambda_l1': 0.9996091749702335, 'lambda_l2': 0.709866942110474, 'learning_rate': 0.05812257987379864, 'max_depth': 8, 'min_data_in_leaf': 22, 'num_iterations': 2251, 'num_leaves': 89}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [734]	valid_0's rmse: 2.69273
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [750]	valid_0's rmse: 2.61725
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [903]	valid_0's rmse: 2.59161
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1185]	valid_0's rmse: 2.65127
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [930]	valid_0's rmse: 2.60785
# [Val_mean] rmse 2.632 mae 1.877 r2 0.599 pcc 0.775
# {'bagging_fraction': 0.6477918820588203, 'feature_fraction': 0.6733982041515579, 'lambda_l1': 0.36649477099663696, 'lambda_l2': 0.2805024436503013, 'learning_rate': 0.04155231666331149, 'max_depth': 9, 'min_data_in_leaf': 24, 'num_iterations': 2999, 'num_leaves': 49}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1566]	valid_0's rmse: 2.68013
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [953]	valid_0's rmse: 2.61075
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1498]	valid_0's rmse: 2.57802
# ...
# [954]	valid_0's rmse: 2.70649
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [617]	valid_0's rmse: 2.63719
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [885]	valid_0's rmse: 2.5855
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1230]	valid_0's rmse: 2.63297
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [659]	valid_0's rmse: 2.64141
# [Val_mean] rmse 2.641 mae 1.892 r2 0.596 pcc 0.773
# {'bagging_fraction': 0.6649622386589458, 'feature_fraction': 0.7883581158064624, 'lambda_l1': 0.32762685973786165, 'lambda_l2': 0.05760837901881247, 'learning_rate': 0.05466617483639209, 'max_depth': 6, 'min_data_in_leaf': 14, 'num_iterations': 2793, 'num_leaves': 63}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1477]	valid_0's rmse: 2.70665
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1138]	valid_0's rmse: 2.62058
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1982]	valid_0's rmse: 2.5704
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1445]	valid_0's rmse: 2.64718
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1109]	valid_0's rmse: 2.62672
# [Val_mean] rmse 2.634 mae 1.890 r2 0.598 pcc 0.775
# {'bagging_fraction': 0.6039062115742614, 'feature_fraction': 0.7614579177643529, 'lambda_l1': 0.1362769065978957, 'lambda_l2': 0.22128839341663756, 'learning_rate': 0.015210100965597113, 'max_depth': 7, 'min_data_in_leaf': 13, 'num_iterations': 1077, 'num_leaves': 39}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1077]	valid_0's rmse: 2.79428
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1077]	valid_0's rmse: 2.69397
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1077]	valid_0's rmse: 2.69919
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1077]	valid_0's rmse: 2.74373
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1077]	valid_0's rmse: 2.72087
# [Val_mean] rmse 2.730 mae 2.038 r2 0.568 pcc 0.756
# {'bagging_fraction': 0.9660132517456139, 'feature_fraction': 0.61798098167016, 'lambda_l1': 0.9355711822573419, 'lambda_l2': 0.5885993152216942, 'learning_rate': 0.04830369815346942, 'max_depth': 7, 'min_data_in_leaf': 27, 'num_iterations': 1594, 'num_leaves': 38}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1582]	valid_0's rmse: 2.68161
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1204]	valid_0's rmse: 2.62057
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1594]	valid_0's rmse: 2.58575
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1586]	valid_0's rmse: 2.65671
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1480]	valid_0's rmse: 2.62421
# [Val_mean] rmse 2.634 mae 1.887 r2 0.598 pcc 0.775
# {'bagging_fraction': 0.728327946357348, 'feature_fraction': 0.7316469252537723, 'lambda_l1': 0.28114497845011993, 'lambda_l2': 0.8637802948983866, 'learning_rate': 0.02899858092173921, 'max_depth': 6, 'min_data_in_leaf': 28, 'num_iterations': 2630, 'num_leaves': 29}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2630]	valid_0's rmse: 2.68688
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [2134]	valid_0's rmse: 2.62029
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2611]	valid_0's rmse: 2.60015
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2628]	valid_0's rmse: 2.65462
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [2622]	valid_0's rmse: 2.62778
# [Val_mean] rmse 2.638 mae 1.909 r2 0.597 pcc 0.773
# {'bagging_fraction': 0.7052877557551852, 'feature_fraction': 0.6647695033674811, 'lambda_l1': 0.060455779729674086, 'lambda_l2': 0.09146978571475226, 'learning_rate': 0.06988476778248282, 'max_depth': 7, 'min_data_in_leaf': 16, 'num_iterations': 2163, 'num_leaves': 55}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [931]	valid_0's rmse: 2.67966
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [822]	valid_0's rmse: 2.63116
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1021]	valid_0's rmse: 2.57628
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1244]	valid_0's rmse: 2.64776
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [686]	valid_0's rmse: 2.63684
# [Val_mean] rmse 2.634 mae 1.888 r2 0.598 pcc 0.775
# {'bagging_fraction': 0.7870888105516479, 'feature_fraction': 0.8587183297217832, 'lambda_l1': 0.5250970507843862, 'lambda_l2': 0.3457874389710789, 'learning_rate': 0.08350783983818781, 'max_depth': 8, 'min_data_in_leaf': 18, 'num_iterations': 2761, 'num_leaves': 83}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [584]	valid_0's rmse: 2.69158
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [460]	valid_0's rmse: 2.6342
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [893]	valid_0's rmse: 2.58088
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [660]	valid_0's rmse: 2.64036
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [544]	valid_0's rmse: 2.62161
# [Val_mean] rmse 2.634 mae 1.881 r2 0.598 pcc 0.775
# {'bagging_fraction': 0.6349692124611345, 'feature_fraction': 0.6899662415667055, 'lambda_l1': 0.763174718262003, 'lambda_l2': 0.5187713414174974, 'learning_rate': 0.03909284212621189, 'max_depth': 7, 'min_data_in_leaf': 10, 'num_iterations': 1152, 'num_leaves': 48}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1122]	valid_0's rmse: 2.69274
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1131]	valid_0's rmse: 2.61699
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1152]	valid_0's rmse: 2.5863
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1135]	valid_0's rmse: 2.64817
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1149]	valid_0's rmse: 2.62231
# [Val_mean] rmse 2.633 mae 1.894 r2 0.598 pcc 0.774
# {'bagging_fraction': 0.9119569547307079, 'feature_fraction': 0.8282570293270684, 'lambda_l1': 0.6290368699294437, 'lambda_l2': 0.038605051960037634, 'learning_rate': 0.09858595122334693, 'max_depth': 6, 'min_data_in_leaf': 19, 'num_iterations': 1787, 'num_leaves': 45}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [664]	valid_0's rmse: 2.70767
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [709]	valid_0's rmse: 2.63662
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [836]	valid_0's rmse: 2.60018
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1165]	valid_0's rmse: 2.6492
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [722]	valid_0's rmse: 2.63304
# [Val_mean] rmse 2.645 mae 1.904 r2 0.595 pcc 0.773
# {'bagging_fraction': 0.7664862681623036, 'feature_fraction': 0.9017762831380145, 'lambda_l1': 0.39643405031140677, 'lambda_l2': 0.46359417877920456, 'learning_rate': 0.0257234030401897, 'max_depth': 7, 'min_data_in_leaf': 21, 'num_iterations': 1512, 'num_leaves': 84}
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1512]	valid_0's rmse: 2.69118
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1505]	valid_0's rmse: 2.6265
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1512]	valid_0's rmse: 2.59543
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1512]	valid_0's rmse: 2.64394
# Training until validation scores don't improve for 60 rounds
# Did not meet early stopping. Best iteration is:
# [1509]	valid_0's rmse: 2.63721
# [Val_mean] rmse 2.639 mae 1.909 r2 0.597 pcc 0.773
# {'bagging_fraction': 0.7998532055831361, 'feature_fraction': 0.9693615974598984, 'lambda_l1': 0.8350431120547188, 'lambda_l2': 0.4027702513237658, 'learning_rate': 0.06128918874996251, 'max_depth': 8, 'min_data_in_leaf': 29, 'num_iterations': 2268, 'num_leaves': 90}
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [699]	valid_0's rmse: 2.69996
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [717]	valid_0's rmse: 2.64046
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [1142]	valid_0's rmse: 2.57997
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [908]	valid_0's rmse: 2.65405
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [943]	valid_0's rmse: 2.64203
# [Val_mean] rmse 2.643 mae 1.892 r2 0.595 pcc 0.773
# 100%|██████████| 60/60 [3:12:16<00:00, 192.28s/trial, best loss: 2.6225190586380593]
# Fold: 1/5
# Training until validation scores don't improve for 60 rounds
# [500]	valid_0's rmse: 2.77116
# [1000]	valid_0's rmse: 2.70248
# [1500]	valid_0's rmse: 2.68608
# Early stopping, best iteration is:
# [1927]	valid_0's rmse: 2.68128
# Fold: 2/5
# Training until validation scores don't improve for 60 rounds
# [500]	valid_0's rmse: 2.67053
# [1000]	valid_0's rmse: 2.62422
# [1500]	valid_0's rmse: 2.6118
# Early stopping, best iteration is:
# [1646]	valid_0's rmse: 2.61035
# Fold: 3/5
# Training until validation scores don't improve for 60 rounds
# [500]	valid_0's rmse: 2.67311
# [1000]	valid_0's rmse: 2.60583
# [1500]	valid_0's rmse: 2.58596
# [2000]	valid_0's rmse: 2.57733
# Did not meet early stopping. Best iteration is:
# [2264]	valid_0's rmse: 2.57476
# Fold: 4/5
# Training until validation scores don't improve for 60 rounds
# [500]	valid_0's rmse: 2.72928
# [1000]	valid_0's rmse: 2.67013
# [1500]	valid_0's rmse: 2.65054
# [2000]	valid_0's rmse: 2.64255
# Early stopping, best iteration is:
# [2117]	valid_0's rmse: 2.64087
# Fold: 5/5
# Training until validation scores don't improve for 60 rounds
# [500]	valid_0's rmse: 2.70347
# [1000]	valid_0's rmse: 2.63678
# [1500]	valid_0's rmse: 2.61515
# [2000]	valid_0's rmse: 2.60748
# Early stopping, best iteration is:
# [2167]	valid_0's rmse: 2.60544
# Dimension of x: 1328
# [Val] rmse 2.6225 mae 1.8784 r2 0.6016 pcc 0.7767 [Test] rmse 2.6924 mae 1.9201 r2 0.5743 pcc 0.7592
#
# Results saved
