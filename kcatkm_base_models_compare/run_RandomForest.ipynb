# %% [markdown]
# # Random Forest

# %%
import os.path
import json
import pandas as pd
# from sklearn.ensemble import RandomForestRegressor
from cuml.ensemble import RandomForestRegressor as curfr
import numpy as np
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from scipy.stats import pearsonr
from hyperopt import fmin, tpe, hp, Trials
from copy import deepcopy
import warnings
warnings.filterwarnings("ignore")
# from sklearnex import patch_sklearn
# patch_sklearn()
current_dir = os.getcwd()

def return_scores(y_true, y_pred):
    y_true = np.array(y_true).ravel()
    y_pred = np.array(y_pred).ravel()
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    pcc = pearsonr(y_true, y_pred)[0]
    return rmse, mae, r2, pcc

def return_x_y(df_filtered):
    y = df_filtered[label_name].values
    mask = ~np.isnan(y)

    # factors
    auxiliary_data = []
    if use_t_ph_embedding:
        ph = df_filtered['ph'].values.reshape(-1, 1)
        t = df_filtered['t'].values.reshape(-1, 1)
        auxiliary_data.append(ph)
        auxiliary_data.append(t)

    if use_mw_logp:
        mw = df_filtered['mw'].values.reshape(-1, 1)
        logp = df_filtered['logp'].values.reshape(-1, 1)
        auxiliary_data.append(mw)
        auxiliary_data.append(logp)

    protein_data = np.array(df_filtered[protein_column].tolist())
    substrate_data = np.array(df_filtered[substrate_column].tolist())
    x = np.hstack([protein_data, substrate_data] + auxiliary_data)

    return x[mask], y[mask]

def search_params(params):
    print(params)
    temp_params = deepcopy(params)
    temp_params["n_estimators"] = int(temp_params["n_estimators"])
    temp_params["max_depth"] = int(temp_params["max_depth"])
    temp_params["min_samples_split"] = int(temp_params["min_samples_split"])
    temp_params["min_samples_leaf"] = int(temp_params["min_samples_leaf"])

    val_scores_list = []
    for train_index, val_index in kf.split(df_train_val):
        df_train = df_train_val.iloc[train_index]
        df_val = df_train_val.iloc[val_index]

        train_x, train_y = return_x_y(df_train)
        val_x, val_y = return_x_y(df_val)

        model = curfr(**temp_params, random_state=random_state)
        model.fit(train_x, train_y)

        val_predicted = model.predict(val_x)
        val_scores = return_scores(val_y, val_predicted)
        val_scores_list.append(val_scores)

    val_scores_mean = np.mean(val_scores_list, axis=0)
    print(f"[Val_mean] rmse {val_scores_mean[0]:.3f} mae {val_scores_mean[1]:.3f} r2 {val_scores_mean[2]:.3f} pcc {val_scores_mean[3]:.3f}")

    return val_scores_mean[0]

def search_best_param(max_evals):
    space = {
        "n_estimators": hp.randint("n_estimators", 10, 300),
        "max_depth": hp.randint("max_depth", 5, 20),
        "min_samples_split": hp.randint("min_samples_split", 2, 20),
        "min_samples_leaf": hp.randint("min_samples_leaf", 1, 20),
        "max_features": hp.uniform("max_features", 0.5, 1.0),
    }

    trials = Trials()
    print(f'[Info] Starting parameter search...')
    best_params = fmin(fn=search_params, space=space, algo=tpe.suggest, max_evals=max_evals, trials=trials)

    best_params['n_estimators'] = int(best_params['n_estimators'])
    best_params['max_depth'] = int(best_params['max_depth'])
    best_params["min_samples_split"] = int(best_params["min_samples_split"])
    best_params["min_samples_leaf"] = int(best_params["min_samples_leaf"])

    # to json
    with open(params_json_path, 'w') as json_file:
        json.dump(best_params, json_file)

    return best_params


# main
protein_column,  substrate_column = 'prott5', 'molebert'
label_name = 'logkcatkm'
random_state = 66
search_max_evals = 60

df_input = pd.read_pickle(f'{current_dir}/../../data_process/dataset/df_all_log_transformed.pkl')
df_train_val, df_test = train_test_split(df_input, test_size=0.2, random_state=random_state)
kf = KFold(n_splits=5, shuffle=True, random_state=random_state)

# save results
results = []
cv_results = []
input_model = 'rf'

use_t_ph_embedding = True
use_mw_logp = True

val_scores_list = []
test_scores_list = []

# search best params
params_json_path = f'{current_dir}/model_dict/{input_model}_params.json'
if os.path.exists(params_json_path):
    with open(params_json_path) as json_file:
        params = json.load(json_file)
else:
    params = search_best_param(search_max_evals)

# train
_params = deepcopy(params)
_params["n_estimators"] = int(_params["n_estimators"])
_params["max_depth"] = int(_params["max_depth"])
_params["min_samples_split"] = int(_params["min_samples_split"])
_params["min_samples_leaf"] = int(_params["min_samples_leaf"])

for fold, (train_index, val_index) in enumerate(kf.split(df_train_val), start=1):
    print(f"Fold: {fold}/5")
    df_train = df_train_val.iloc[train_index]
    df_val = df_train_val.iloc[val_index]

    train_x, train_y = return_x_y(df_train)
    val_x, val_y = return_x_y(df_val)
    test_x, test_y = return_x_y(df_test)

    model = curfr(**_params, random_state=random_state)
    model.fit(train_x, train_y)

    val_predicted = model.predict(val_x)
    val_scores = return_scores(val_y, val_predicted)
    val_scores_list.append(val_scores)

    test_predicted = model.predict(test_x)
    test_scores = return_scores(test_y, test_predicted)
    test_scores_list.append(test_scores)

    # fold
    cv_results.append([
        fold,
        val_scores[0], val_scores[1], val_scores[2], val_scores[3],
        test_scores[0], test_scores[1], test_scores[2], test_scores[3]
    ])

# mean
val_scores_mean = np.mean(val_scores_list, axis=0)
test_scores_mean = np.mean(test_scores_list, axis=0)
print(f"Dimension of x: {train_x.shape[1]}")
print(f"[Val] rmse {val_scores_mean[0]:.4f} mae {val_scores_mean[1]:.4f} r2 {val_scores_mean[2]:.4f} pcc {val_scores_mean[3]:.4f} "
      f"[Test] rmse {test_scores_mean[0]:.4f} mae {test_scores_mean[1]:.4f} r2 {test_scores_mean[2]:.4f} pcc {test_scores_mean[3]:.4f}\n")

# save cvs
df_cv_results = pd.DataFrame(cv_results, columns=[
    "Fold",
    "Val_RMSE", "Val_MAE", "Val_R2", "Val_PCC",
    "Test_RMSE", "Test_MAE", "Test_R2", "Test_PCC"])
df_cv_results.to_excel(f"{current_dir}/results/{input_model}_cv_results.xlsx", index=False)
print("Results saved")
# Out:
# [Info] Starting parameter search...
# {'max_depth': np.int64(5), 'max_features': 0.8137216308067569, 'min_samples_leaf': np.int64(10), 'min_samples_split': np.int64(18), 'n_estimators': np.int64(250)}
# [Val_mean] rmse 3.696 mae 2.910 r2 0.209 pcc 0.505
# {'max_depth': np.int64(17), 'max_features': 0.7104273217229683, 'min_samples_leaf': np.int64(19), 'min_samples_split': np.int64(5), 'n_estimators': np.int64(226)}
# [Val_mean] rmse 2.931 mae 2.199 r2 0.502 pcc 0.719
# {'max_depth': np.int64(9), 'max_features': 0.8394721722804144, 'min_samples_leaf': np.int64(7), 'min_samples_split': np.int64(9), 'n_estimators': np.int64(155)}
# [Val_mean] rmse 3.191 mae 2.478 r2 0.410 pcc 0.674
# {'max_depth': np.int64(9), 'max_features': 0.5764935595171923, 'min_samples_leaf': np.int64(15), 'min_samples_split': np.int64(15), 'n_estimators': np.int64(186)}
# [Val_mean] rmse 3.214 mae 2.489 r2 0.402 pcc 0.670
# {'max_depth': np.int64(12), 'max_features': 0.7856122528754848, 'min_samples_leaf': np.int64(6), 'min_samples_split': np.int64(6), 'n_estimators': np.int64(53)}
# [Val_mean] rmse 2.944 mae 2.235 r2 0.498 pcc 0.719
# {'max_depth': np.int64(9), 'max_features': 0.833472112277762, 'min_samples_leaf': np.int64(5), 'min_samples_split': np.int64(15), 'n_estimators': np.int64(89)}
# [Val_mean] rmse 3.188 mae 2.479 r2 0.412 pcc 0.674
# {'max_depth': np.int64(12), 'max_features': 0.5099303149792598, 'min_samples_leaf': np.int64(14), 'min_samples_split': np.int64(2), 'n_estimators': np.int64(116)}
# [Val_mean] rmse 2.999 mae 2.281 r2 0.479 pcc 0.710
# {'max_depth': np.int64(8), 'max_features': 0.8501838116763563, 'min_samples_leaf': np.int64(18), 'min_samples_split': np.int64(3), 'n_estimators': np.int64(251)}
# [Val_mean] rmse 3.328 mae 2.589 r2 0.359 pcc 0.639
# {'max_depth': np.int64(16), 'max_features': 0.9139217216771878, 'min_samples_leaf': np.int64(3), 'min_samples_split': np.int64(2), 'n_estimators': np.int64(214)}
# [Val_mean] rmse 2.798 mae 2.075 r2 0.546 pcc 0.743
# {'max_depth': np.int64(5), 'max_features': 0.8181823106711705, 'min_samples_leaf': np.int64(19), 'min_samples_split': np.int64(19), 'n_estimators': np.int64(133)}
# [Val_mean] rmse 3.700 mae 2.909 r2 0.207 pcc 0.502
# {'max_depth': np.int64(8), 'max_features': 0.6369785023738603, 'min_samples_leaf': np.int64(15), 'min_samples_split': np.int64(3), 'n_estimators': np.int64(195)}
# [Val_mean] rmse 3.324 mae 2.588 r2 0.360 pcc 0.643
# {'max_depth': np.int64(6), 'max_features': 0.8412388192679547, 'min_samples_leaf': np.int64(8), 'min_samples_split': np.int64(3), 'n_estimators': np.int64(100)}
# [Val_mean] rmse 3.573 mae 2.809 r2 0.261 pcc 0.557
# {'max_depth': np.int64(18), 'max_features': 0.6812539710696954, 'min_samples_leaf': np.int64(16), 'min_samples_split': np.int64(19), 'n_estimators': np.int64(124)}
# [Val_mean] rmse 2.899 mae 2.166 r2 0.513 pcc 0.725
# {'max_depth': np.int64(17), 'max_features': 0.6456209244996305, 'min_samples_leaf': np.int64(19), 'min_samples_split': np.int64(19), 'n_estimators': np.int64(182)}
# [Val_mean] rmse 2.932 mae 2.201 r2 0.502 pcc 0.720
# {'max_depth': np.int64(8), 'max_features': 0.6067478196879699, 'min_samples_leaf': np.int64(19), 'min_samples_split': np.int64(3), 'n_estimators': np.int64(176)}
# [Val_mean] rmse 3.332 mae 2.593 r2 0.357 pcc 0.641
# {'max_depth': np.int64(18), 'max_features': 0.809911390035918, 'min_samples_leaf': np.int64(14), 'min_samples_split': np.int64(7), 'n_estimators': np.int64(123)}
# [Val_mean] rmse 2.882 mae 2.148 r2 0.519 pcc 0.728
# {'max_depth': np.int64(11), 'max_features': 0.8947552143895477, 'min_samples_leaf': np.int64(12), 'min_samples_split': np.int64(18), 'n_estimators': np.int64(15)}
# [Val_mean] rmse 3.079 mae 2.352 r2 0.451 pcc 0.686
# {'max_depth': np.int64(11), 'max_features': 0.7873088406223215, 'min_samples_leaf': np.int64(14), 'min_samples_split': np.int64(8), 'n_estimators': np.int64(173)}
# [Val_mean] rmse 3.041 mae 2.325 r2 0.464 pcc 0.703
# {'max_depth': np.int64(5), 'max_features': 0.7726406970555795, 'min_samples_leaf': np.int64(3), 'min_samples_split': np.int64(16), 'n_estimators': np.int64(214)}
# [Val_mean] rmse 3.694 mae 2.911 r2 0.210 pcc 0.507
# {'max_depth': np.int64(7), 'max_features': 0.5039158492537664, 'min_samples_leaf': np.int64(19), 'min_samples_split': np.int64(4), 'n_estimators': np.int64(252)}
# [Val_mean] rmse 3.453 mae 2.702 r2 0.310 pcc 0.608
# {'max_depth': np.int64(16), 'max_features': 0.9746997194971688, 'min_samples_leaf': np.int64(2), 'min_samples_split': np.int64(7), 'n_estimators': np.int64(105)}
# [Val_mean] rmse 2.797 mae 2.073 r2 0.547 pcc 0.743
# {'max_depth': np.int64(16), 'max_features': 0.9782712549001589, 'min_samples_leaf': np.int64(2), 'min_samples_split': np.int64(7), 'n_estimators': np.int64(262)}
# [Val_mean] rmse 2.792 mae 2.071 r2 0.548 pcc 0.744
# {'max_depth': np.int64(16), 'max_features': 0.9994172445382171, 'min_samples_leaf': np.int64(9), 'min_samples_split': np.int64(7), 'n_estimators': np.int64(108)}
# [Val_mean] rmse 2.852 mae 2.122 r2 0.529 pcc 0.733
# {'max_depth': np.int64(16), 'max_features': 0.9792599398414263, 'min_samples_leaf': np.int64(2), 'min_samples_split': np.int64(14), 'n_estimators': np.int64(104)}
# [Val_mean] rmse 2.810 mae 2.086 r2 0.542 pcc 0.741
# {'max_depth': np.int64(13), 'max_features': 0.9565283659292818, 'min_samples_leaf': np.int64(2), 'min_samples_split': np.int64(11), 'n_estimators': np.int64(43)}
# [Val_mean] rmse 2.891 mae 2.181 r2 0.516 pcc 0.726
# {'max_depth': np.int64(15), 'max_features': 0.9523739137537379, 'min_samples_leaf': np.int64(2), 'min_samples_split': np.int64(10), 'n_estimators': np.int64(162)}
# [Val_mean] rmse 2.814 mae 2.097 r2 0.541 pcc 0.741
# {'max_depth': np.int64(14), 'max_features': 0.8940310083122752, 'min_samples_leaf': np.int64(1), 'min_samples_split': np.int64(7), 'n_estimators': np.int64(262)}
# [Val_mean] rmse 2.826 mae 2.120 r2 0.537 pcc 0.740
# {'max_depth': np.int64(19), 'max_features': 0.9981859201618125, 'min_samples_leaf': np.int64(13), 'min_samples_split': np.int64(13), 'n_estimators': np.int64(209)}
# [Val_mean] rmse 2.871 mae 2.134 r2 0.522 pcc 0.729
# {'max_depth': np.int64(10), 'max_features': 0.9301196098313392, 'min_samples_leaf': np.int64(17), 'min_samples_split': np.int64(12), 'n_estimators': np.int64(281)}
# [Val_mean] rmse 3.127 mae 2.405 r2 0.434 pcc 0.685
# {'max_depth': np.int64(16), 'max_features': 0.8780335531105061, 'min_samples_leaf': np.int64(11), 'min_samples_split': np.int64(17), 'n_estimators': np.int64(105)}
# [Val_mean] rmse 2.871 mae 2.142 r2 0.522 pcc 0.730
# {'max_depth': np.int64(16), 'max_features': 0.7185215140321045, 'min_samples_leaf': np.int64(4), 'min_samples_split': np.int64(7), 'n_estimators': np.int64(70)}
# [Val_mean] rmse 2.803 mae 2.080 r2 0.545 pcc 0.742
# {'max_depth': np.int64(16), 'max_features': 0.9631692094145278, 'min_samples_leaf': np.int64(10), 'min_samples_split': np.int64(5), 'n_estimators': np.int64(297)}
# [Val_mean] rmse 2.862 mae 2.130 r2 0.526 pcc 0.732
# {'max_depth': np.int64(14), 'max_features': 0.7373390862195875, 'min_samples_leaf': np.int64(2), 'min_samples_split': np.int64(9), 'n_estimators': np.int64(222)}
# [Val_mean] rmse 2.828 mae 2.121 r2 0.537 pcc 0.741
# {'max_depth': np.int64(15), 'max_features': 0.8711069974128115, 'min_samples_leaf': np.int64(7), 'min_samples_split': np.int64(7), 'n_estimators': np.int64(259)}
# [Val_mean] rmse 2.844 mae 2.123 r2 0.531 pcc 0.736
# {'max_depth': np.int64(19), 'max_features': 0.935837414902711, 'min_samples_leaf': np.int64(2), 'min_samples_split': np.int64(6), 'n_estimators': np.int64(79)}
# [Val_mean] rmse 2.779 mae 2.043 r2 0.553 pcc 0.745
# {'max_depth': np.int64(19), 'max_features': 0.9264846999456988, 'min_samples_leaf': np.int64(6), 'min_samples_split': np.int64(6), 'n_estimators': np.int64(79)}
# [Val_mean] rmse 2.809 mae 2.071 r2 0.543 pcc 0.740
# {'max_depth': np.int64(19), 'max_features': 0.9977449413521552, 'min_samples_leaf': np.int64(5), 'min_samples_split': np.int64(6), 'n_estimators': np.int64(246)}
# [Val_mean] rmse 2.789 mae 2.054 r2 0.549 pcc 0.744
# {'max_depth': np.int64(19), 'max_features': 0.9962466678323387, 'min_samples_leaf': np.int64(5), 'min_samples_split': np.int64(6), 'n_estimators': np.int64(149)}
# [Val_mean] rmse 2.794 mae 2.058 r2 0.548 pcc 0.743
# {'max_depth': np.int64(19), 'max_features': 0.9372005435373129, 'min_samples_leaf': np.int64(5), 'min_samples_split': np.int64(6), 'n_estimators': np.int64(246)}
# [Val_mean] rmse 2.794 mae 2.058 r2 0.548 pcc 0.743
# {'max_depth': np.int64(19), 'max_features': 0.5257285764399622, 'min_samples_leaf': np.int64(18), 'min_samples_split': np.int64(6), 'n_estimators': np.int64(85)}
# [Val_mean] rmse 2.922 mae 2.190 r2 0.505 pcc 0.720
# {'max_depth': np.int64(12), 'max_features': 0.5587292822248635, 'min_samples_leaf': np.int64(5), 'min_samples_split': np.int64(15), 'n_estimators': np.int64(45)}
# [Val_mean] rmse 2.950 mae 2.248 r2 0.496 pcc 0.719
# {'max_depth': np.int64(9), 'max_features': 0.8681062385914935, 'min_samples_leaf': np.int64(8), 'min_samples_split': np.int64(6), 'n_estimators': np.int64(27)}
# [Val_mean] rmse 3.213 mae 2.490 r2 0.402 pcc 0.663
# {'max_depth': np.int64(6), 'max_features': 0.9058424354555616, 'min_samples_leaf': np.int64(16), 'min_samples_split': np.int64(10), 'n_estimators': np.int64(150)}
# [Val_mean] rmse 3.573 mae 2.804 r2 0.261 pcc 0.556
# {'max_depth': np.int64(17), 'max_features': 0.6901409273329672, 'min_samples_leaf': np.int64(1), 'min_samples_split': np.int64(2), 'n_estimators': np.int64(136)}
# [Val_mean] rmse 2.763 mae 2.039 r2 0.558 pcc 0.750
# {'max_depth': np.int64(17), 'max_features': 0.676706592393622, 'min_samples_leaf': np.int64(1), 'min_samples_split': np.int64(2), 'n_estimators': np.int64(129)}
# [Val_mean] rmse 2.764 mae 2.039 r2 0.558 pcc 0.749
# {'max_depth': np.int64(17), 'max_features': 0.6828374465484726, 'min_samples_leaf': np.int64(1), 'min_samples_split': np.int64(2), 'n_estimators': np.int64(144)}
# [Val_mean] rmse 2.762 mae 2.039 r2 0.558 pcc 0.750
# {'max_depth': np.int64(17), 'max_features': 0.5996112033524105, 'min_samples_leaf': np.int64(1), 'min_samples_split': np.int64(2), 'n_estimators': np.int64(136)}
# [Val_mean] rmse 2.763 mae 2.042 r2 0.558 pcc 0.750
# {'max_depth': np.int64(17), 'max_features': 0.5974769223488801, 'min_samples_leaf': np.int64(1), 'min_samples_split': np.int64(2), 'n_estimators': np.int64(41)}
# [Val_mean] rmse 2.782 mae 2.053 r2 0.552 pcc 0.745
# {'max_depth': np.int64(17), 'max_features': 0.5403660124723346, 'min_samples_leaf': np.int64(1), 'min_samples_split': np.int64(2), 'n_estimators': np.int64(144)}
# [Val_mean] rmse 2.765 mae 2.043 r2 0.557 pcc 0.749
# {'max_depth': np.int64(17), 'max_features': 0.6516563617054845, 'min_samples_leaf': np.int64(12), 'min_samples_split': np.int64(16), 'n_estimators': np.int64(188)}
# [Val_mean] rmse 2.864 mae 2.135 r2 0.525 pcc 0.732
# {'max_depth': np.int64(7), 'max_features': 0.613713017843073, 'min_samples_leaf': np.int64(15), 'min_samples_split': np.int64(4), 'n_estimators': np.int64(130)}
# [Val_mean] rmse 3.450 mae 2.700 r2 0.311 pcc 0.607
# {'max_depth': np.int64(10), 'max_features': 0.5766644553282724, 'min_samples_leaf': np.int64(13), 'min_samples_split': np.int64(18), 'n_estimators': np.int64(122)}
# [Val_mean] rmse 3.118 mae 2.403 r2 0.437 pcc 0.690
# {'max_depth': np.int64(13), 'max_features': 0.7470202841710053, 'min_samples_leaf': np.int64(11), 'min_samples_split': np.int64(8), 'n_estimators': np.int64(20)}
# [Val_mean] rmse 2.971 mae 2.242 r2 0.489 pcc 0.708
# {'max_depth': np.int64(18), 'max_features': 0.6242964210947386, 'min_samples_leaf': np.int64(9), 'min_samples_split': np.int64(2), 'n_estimators': np.int64(128)}
# [Val_mean] rmse 2.829 mae 2.097 r2 0.536 pcc 0.738
# {'max_depth': np.int64(5), 'max_features': 0.6628203308742616, 'min_samples_leaf': np.int64(17), 'min_samples_split': np.int64(14), 'n_estimators': np.int64(202)}
# [Val_mean] rmse 3.701 mae 2.911 r2 0.207 pcc 0.506
# {'max_depth': np.int64(17), 'max_features': 0.6998442445173315, 'min_samples_leaf': np.int64(3), 'min_samples_split': np.int64(11), 'n_estimators': np.int64(146)}
# [Val_mean] rmse 2.783 mae 2.058 r2 0.551 pcc 0.747
# {'max_depth': np.int64(8), 'max_features': 0.7166388414420459, 'min_samples_leaf': np.int64(1), 'min_samples_split': np.int64(13), 'n_estimators': np.int64(267)}
# [Val_mean] rmse 3.293 mae 2.579 r2 0.372 pcc 0.652
# {'max_depth': np.int64(11), 'max_features': 0.7712537683448691, 'min_samples_leaf': np.int64(10), 'min_samples_split': np.int64(12), 'n_estimators': np.int64(99)}
# [Val_mean] rmse 3.023 mae 2.312 r2 0.471 pcc 0.706
# {'max_depth': np.int64(12), 'max_features': 0.5893341258337439, 'min_samples_leaf': np.int64(4), 'min_samples_split': np.int64(17), 'n_estimators': np.int64(265)}
# [Val_mean] rmse 2.934 mae 2.236 r2 0.501 pcc 0.725
# {'max_depth': np.int64(9), 'max_features': 0.5559037446146978, 'min_samples_leaf': np.int64(6), 'min_samples_split': np.int64(19), 'n_estimators': np.int64(288)}
# [Val_mean] rmse 3.192 mae 2.482 r2 0.410 pcc 0.677
# 100%|██████████| 60/60 [36:49<00:00, 36.82s/trial, best loss: 2.7620328224207134]
# Fold: 1/5
# Fold: 2/5
# Fold: 3/5
# Fold: 4/5
# Fold: 5/5
# Dimension of x: 1328
# [Val] rmse 2.7612 mae 2.0374 r2 0.5583 pcc 0.7501 [Test] rmse 2.8092 mae 2.0735 r2 0.5366 pcc 0.7339
#
# Results saved
